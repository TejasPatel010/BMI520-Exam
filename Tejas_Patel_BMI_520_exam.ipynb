# %%
import pandas as pd
import seaborn as sns
import matplotlib
import  matplotlib.pyplot as plt
import numpy as np

# %%
iris_df = sns.load_dataset('iris')
iris_df.head
# Out:
# <bound method NDFrame.head of      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]>

# %%
plt.hist(iris_df["sepal_length"], bins=split_up_interval(120, 570, 20), cumulative=True)
plt.xlabel("sepal_length")
plt.ylabel("Count")
plt.ylim(0, 50)
# Out:
# (0.0, 50.0)

# %%
sns.histplot(data=iris_df, x="sepal_length")
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data=iris_df, x="sepal_width")
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data=iris_df, x="petal_width")
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.histplot(data=iris_df, x="petal_length")
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.boxplot(x='sepal_length', y='sepal_width', data=iris_df, palette="Blues")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.boxplot(x='petal_length', y='petal_width', data=iris_df, palette="Blues")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.boxplot(x='petal_length', y='petal_width', data=iris_df, color="Red")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>

# %%
sns.boxplot(x='petal_length', y='petal_width', data=iris_df, color="Red")
# Out:
# <Axes: xlabel='petal_length', ylabel='petal_width'>
